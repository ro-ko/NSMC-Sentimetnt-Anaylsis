# %% [markdown]
# # 0. Dependency

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
import os

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7f7430aa3040>)

# %% [markdown]
# # 1. Load Dataset

# %%
train_data = pd.read_table('ratings_train.txt')
test_data = pd.read_table('ratings_test.txt')

# %%
print(f"train_data nums : {len(train_data)}")
train_data.head()
# Out:
# train_data nums : 150000
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
print(f"test_data nums : {len(test_data)}")
test_data.head()
# Out:
# test_data nums : 50000
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %% [markdown]
# # 2-1. Data Preoprocess
# ## Train_data
# ### Remove Duplicate

# %%
# Check duplicate

print(f"Unique documents num: {train_data['document'].nunique()}")
print(f"Duplicated documents num : {len(train_data)-train_data['document'].nunique()}")

# Remove duplicates

train_data.drop_duplicates(subset=['document'], inplace=True)
# Out:
# Unique documents num: 146182
# Duplicated documents num : 3818

# %% [markdown]
# ### Remove Null

# %%
# Check null data

print(f"IsNull : {train_data.isnull().values.any()}")
print(f"Null train_data : {len(train_data.loc[train_data.document.isnull()])}\n")
print(train_data.loc[train_data.document.isnull()])

# Remove null data

train_data = train_data.dropna(how = 'any')
# Out:
# IsNull : True
# Null train_data : 1
#
#             id document  label
# 25857  2172111      NaN      1

# %% [markdown]
# ### Remove exclamation mark with Regular Expression

# %%
train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data[:5]
# Out:
# <ipython-input-10-9c6253be230d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
#          id                                           document  label
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1

# %%
# Check null data
# Change white space 2 empty space

train_data['document'] = train_data['document'].str.replace('^ +', "")
train_data['document'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())

train_data.loc[train_data.document.isnull()][:5]
# Out:
# <ipython-input-11-eb86e41c46bf>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'] = train_data['document'].str.replace('^ +', "")
# id            0
# document    789
# label         0
# dtype: int64
#            id document  label
# 404   4221289      NaN      0
# 412   9509970      NaN      1
# 470  10147571      NaN      1
# 584   7117896      NaN      0
# 593   6478189      NaN      0

# %%
# Remove null data again

train_data = train_data.dropna(how = 'any')
print(len(train_data))
# Out:
# 145393

# %% [markdown]
# ## Test_data
# ### Remove Duplicate

# %%
# Check duplicate

print(f"Unique test_data documents num: {test_data['document'].nunique()}")
print(f"Duplicated test_data documents num : {len(test_data)-test_data['document'].nunique()}\n")

# Remove duplicates

test_data.drop_duplicates(subset=['document'], inplace=True)
# Out:
# Unique test_data documents num: 49157
# Duplicated test_data documents num : 843

# %% [markdown]
# ### Remove Null

# %%
# Check null data

print(f"IsNull : {test_data.isnull().values.any()}")
print(f"Null train_data : {len(test_data.loc[test_data.document.isnull()])}\n")
print(test_data.loc[test_data.document.isnull()])

# Remove null data

test_data = test_data.dropna(how = 'any')
# Out:
# IsNull : True
# Null train_data : 1
#
#           id document  label
# 5746  402110      NaN      1

# %% [markdown]
# ### Remove exclamation mark with Regular Expression

# %% [markdown]
# We can remove exclamarion mark using regular expression
#
# Constant range : ㄱ ~ ㅎ -> 3131 ~ 314E
# Vowel range : ㅏ ~ ㅣ -> 314F ~ 3163\
# (https://www.unicode.org/charts/PDF/U3130.pdf)
#
# Complete Korean lanuage range : 가 ~ 힣\
# https://www.unicode.org/charts/PDF/UAC00.pdf

# %%
test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
test_data[:5]
# Out:
# <ipython-input-15-fc68a8c37bd6>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# <ipython-input-15-fc68a8c37bd6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
#         id                                   document  label
# 0  6270596                                        굳 ㅋ      1
# 1  9274899                                                 0
# 2  8544678           뭐야 이 평점들은 나쁘진 않지만 점 짜리는 더더욱 아니잖아      0
# 3  6825595                  지루하지는 않은데 완전 막장임 돈주고 보기에는      0
# 4  6723715  만 아니었어도 별 다섯 개 줬을텐데 왜 로 나와서 제 심기를 불편하게 하죠      0

# %%
# Check null data
# Change white space 2 empty space

test_data['document'] = test_data['document'].str.replace('^ +', "")
test_data['document'].replace('', np.nan, inplace=True)
print(test_data.isnull().sum())

test_data.loc[test_data.document.isnull()][:5]
# Out:
# id            0
# document    305
# label         0
# dtype: int64
# <ipython-input-16-567d926e84b2>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document'] = test_data['document'].str.replace('^ +', "")
#           id document  label
# 1    9274899      NaN      0
# 116  6910486      NaN      1
# 254  4976468      NaN      0
# 468  7517102      NaN      0
# 504  2096424      NaN      0

# %%
# Remove null data again

test_data = test_data.dropna(how = 'any')
print(len(test_data))
# Out:
# 48852

# %% [markdown]
# # 2-2. Check Dataset Imbalance

# %%
# Check train_data distribution

train_data['label'].value_counts().plot(kind = 'bar')
print(train_data['label'].value_counts())
# Out:
# 0    73043
# 1    72350
# Name: label, dtype: int64

# %%
# Check test_data distribution

test_data['label'].value_counts().plot(kind = 'bar')
print(test_data['label'].value_counts())
# Out:
# 1    24520
# 0    24332
# Name: label, dtype: int64

# %% [markdown]
# Train, Test dataset are well distributed as above.

# %% [markdown]
# # 2-3. Padding

# %%
# Split data, label

X_train = np.array(train_data['document'])
X_test = np.array(test_data['document'])
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# Plot document length distribution

print('Max length of document :',max(len(review) for review in X_train))
print('Avg length of document :',sum(map(len, X_train))/len(X_train))
plt.hist([len(review) for review in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# Max length of document : 140
# Avg length of document : 33.08291320765099

# %% [markdown]
# The length of the longest document is 140, and the length distribution of the entire document has a length of around 20 in general.
#
# We need to make all samples of X_train and X_test **the same length to a specific length** so that the model can handle it. Then what is **the optimal value for max_len** that will allow most reviews to avoid truncating document information?
#
# Let's check the ratio of total documents whose length is less than or equal to max_len.
#
# #### Ablation experiment : When we fix the optimal length, is there information lose in documents?
#
# Compare padding -> Optimal length contanining 90%, 95%, 99% / Max length

# %%
def below_threshold_len(max_len, nested_list):
    count = 0
    for sentence in nested_list:
        if(len(sentence) <= max_len):
            count = count + 1
    print(f'Ratio of document which is equal or less than length {max_len} in entire document : {(count / len(nested_list)*100)}')
    return (count / len(nested_list)*100)

# %%
max_len = [i for i in range(1,141)]
ratio = [] 

for value in max_len:
    ratio.append(below_threshold_len(value, X_train))

plt.bar(max_len,ratio)
plt.xlabel('length of samples')
plt.ylabel('ratio of equal or less than samples')
plt.show()

print(f"mean : {np.mean(ratio)}, std : {np.std(ratio)}, var : {np.var(ratio)} \n")
print("By results of function choose optimal length roughly, \n"
        "90% : length 70 (89.87502837137964%) \n" 
        "95% : length 100 (94.86426444189198) \n"
        "99% : length 130 (98.81493606982454)")
# Out:
# Ratio of document which is equal or less than length 1 in entire document : 0.18364020276079315
# Ratio of document which is equal or less than length 2 in entire document : 0.7098003342664365
# Ratio of document which is equal or less than length 3 in entire document : 1.4175372954681449
# Ratio of document which is equal or less than length 4 in entire document : 2.4712331405225836
# Ratio of document which is equal or less than length 5 in entire document : 3.5421237611164225
# Ratio of document which is equal or less than length 6 in entire document : 4.935588370829407
# Ratio of document which is equal or less than length 7 in entire document : 6.486557124483297
# Ratio of document which is equal or less than length 8 in entire document : 8.296135302249764
# Ratio of document which is equal or less than length 9 in entire document : 10.301046130143817
# Ratio of document which is equal or less than length 10 in entire document : 12.680803064796791
# Ratio of document which is equal or less than length 11 in entire document : 15.35974909383533
# Ratio of document which is equal or less than length 12 in entire document : 18.251222548540852
# Ratio of document which is equal or less than length 13 in entire document : 21.22247976174919
# Ratio of document which is equal or less than length 14 in entire document : 24.16897649818079
# Ratio of document which is equal or less than length 15 in entire document : 27.0666400720805
# Ratio of document which is equal or less than length 16 in entire document : 29.81917974042767
# Ratio of document which is equal or less than length 17 in entire document : 32.53045194748027
# Ratio of document which is equal or less than length 18 in entire document : 35.14199445640437
# Ratio of document which is equal or less than length 19 in entire document : 37.68200669908455
# Ratio of document which is equal or less than length 20 in entire document : 40.112660169334156
# Ratio of document which is equal or less than length 21 in entire document : 42.46490546312408
# Ratio of document which is equal or less than length 22 in entire document : 44.75112281884272
# Ratio of document which is equal or less than length 23 in entire document : 47.01464307084935
# Ratio of document which is equal or less than length 24 in entire document : 49.157799894080185
# Ratio of document which is equal or less than length 25 in entire document : 51.32571719408775
# Ratio of document which is equal or less than length 26 in entire document : 53.40903619844146
# Ratio of document which is equal or less than length 27 in entire document : 55.43320517493965
# Ratio of document which is equal or less than length 28 in entire document : 57.474568926977234
# Ratio of document which is equal or less than length 29 in entire document : 59.38800354900167
# Ratio of document which is equal or less than length 30 in entire document : 61.306940499198724
# Ratio of document which is equal or less than length 31 in entire document : 63.03673491846238
# Ratio of document which is equal or less than length 32 in entire document : 64.76102700955342
# Ratio of document which is equal or less than length 33 in entire document : 66.36770683595496
# Ratio of document which is equal or less than length 34 in entire document : 67.86777905401223
# Ratio of document which is equal or less than length 35 in entire document : 69.36647569002633
# Ratio of document which is equal or less than length 36 in entire document : 70.83559731211268
# Ratio of document which is equal or less than length 37 in entire document : 72.2455689063435
# Ratio of document which is equal or less than length 38 in entire document : 73.59639047271877
# Ratio of document which is equal or less than length 39 in entire document : 74.92932947253307
# Ratio of document which is equal or less than length 40 in entire document : 76.2925312772967
# Ratio of document which is equal or less than length 41 in entire document : 77.65435750001718
# Ratio of document which is equal or less than length 42 in entire document : 78.87449877229302
# Ratio of document which is equal or less than length 43 in entire document : 79.95364288514578
# Ratio of document which is equal or less than length 44 in entire document : 80.81200608007263
# Ratio of document which is equal or less than length 45 in entire document : 81.45990522239723
# Ratio of document which is equal or less than length 46 in entire document : 81.96818278734189
# Ratio of document which is equal or less than length 47 in entire document : 82.46270453185505
# Ratio of document which is equal or less than length 48 in entire document : 82.94209487389351
# Ratio of document which is equal or less than length 49 in entire document : 83.35339390479596
# Ratio of document which is equal or less than length 50 in entire document : 83.79977027779879
# Ratio of document which is equal or less than length 51 in entire document : 84.1835576678382
# Ratio of document which is equal or less than length 52 in entire document : 84.57559855013652
# Ratio of document which is equal or less than length 53 in entire document : 84.95319582098175
# Ratio of document which is equal or less than length 54 in entire document : 85.30053028687765
# Ratio of document which is equal or less than length 55 in entire document : 85.67331302057183
# Ratio of document which is equal or less than length 56 in entire document : 86.00689166603618
# Ratio of document which is equal or less than length 57 in entire document : 86.33565577434952
# Ratio of document which is equal or less than length 58 in entire document : 86.63622045077824
# Ratio of document which is equal or less than length 59 in entire document : 86.95054094763847
# Ratio of document which is equal or less than length 60 in entire document : 87.24353992282985
# Ratio of document which is equal or less than length 61 in entire document : 87.5372266890428
# Ratio of document which is equal or less than length 62 in entire document : 87.81578205278109
# Ratio of document which is equal or less than length 63 in entire document : 88.10259090877828
# Ratio of document which is equal or less than length 64 in entire document : 88.38733639171075
# Ratio of document which is equal or less than length 65 in entire document : 88.67139408362164
# Ratio of document which is equal or less than length 66 in entire document : 88.90042849380644
# Ratio of document which is equal or less than length 67 in entire document : 89.16729141017792
# Ratio of document which is equal or less than length 68 in entire document : 89.40664268568638
# Ratio of document which is equal or less than length 69 in entire document : 89.66043757264792
# Ratio of document which is equal or less than length 70 in entire document : 89.87502837137964
# Ratio of document which is equal or less than length 71 in entire document : 90.09924824441342
# Ratio of document which is equal or less than length 72 in entire document : 90.30214659577834
# Ratio of document which is equal or less than length 73 in entire document : 90.5126106483806
# Ratio of document which is equal or less than length 74 in entire document : 90.73270377528492
# Ratio of document which is equal or less than length 75 in entire document : 90.94454340993032
# Ratio of document which is equal or less than length 76 in entire document : 91.15363188048943
# Ratio of document which is equal or less than length 77 in entire document : 91.34896453061701
# Ratio of document which is equal or less than length 78 in entire document : 91.52847798724835
# Ratio of document which is equal or less than length 79 in entire document : 91.7251862194191
# Ratio of document which is equal or less than length 80 in entire document : 91.90607525809358
# Ratio of document which is equal or less than length 81 in entire document : 92.09040325187595
# Ratio of document which is equal or less than length 82 in entire document : 92.28229694689566
# Ratio of document which is equal or less than length 83 in entire document : 92.44874237411705
# Ratio of document which is equal or less than length 84 in entire document : 92.61725117440317
# Ratio of document which is equal or less than length 85 in entire document : 92.77888206447354
# Ratio of document which is equal or less than length 86 in entire document : 92.94188853658704
# Ratio of document which is equal or less than length 87 in entire document : 93.09182697929062
# Ratio of document which is equal or less than length 88 in entire document : 93.24245321301575
# Ratio of document which is equal or less than length 89 in entire document : 93.37794804426623
# Ratio of document which is equal or less than length 90 in entire document : 93.5333888151424
# Ratio of document which is equal or less than length 91 in entire document : 93.66819585537131
# Ratio of document which is equal or less than length 92 in entire document : 93.80850522377281
# Ratio of document which is equal or less than length 93 in entire document : 93.94812680115274
# Ratio of document which is equal or less than length 94 in entire document : 94.08018267729533
# Ratio of document which is equal or less than length 95 in entire document : 94.23149670204205
# Ratio of document which is equal or less than length 96 in entire document : 94.37386944350828
# Ratio of document which is equal or less than length 97 in entire document : 94.49216949921936
# Ratio of document which is equal or less than length 98 in entire document : 94.61941083821091
# Ratio of document which is equal or less than length 99 in entire document : 94.74665217720248
# Ratio of document which is equal or less than length 100 in entire document : 94.86426444189198
# Ratio of document which is equal or less than length 101 in entire document : 94.9811889155599
# Ratio of document which is equal or less than length 102 in entire document : 95.10705467250831
# Ratio of document which is equal or less than length 103 in entire document : 95.2274181012841
# Ratio of document which is equal or less than length 104 in entire document : 95.35465944027567
# Ratio of document which is equal or less than length 105 in entire document : 95.47502286905146
# Ratio of document which is equal or less than length 106 in entire document : 95.58369385046048
# Ratio of document which is equal or less than length 107 in entire document : 95.69442820493421
# Ratio of document which is equal or less than length 108 in entire document : 95.79278232101957
# Ratio of document which is equal or less than length 109 in entire document : 95.89801434732071
# Ratio of document which is equal or less than length 110 in entire document : 96.01425102996706
# Ratio of document which is equal or less than length 111 in entire document : 96.12017084728976
# Ratio of document which is equal or less than length 112 in entire document : 96.21164705315937
# Ratio of document which is equal or less than length 113 in entire document : 96.33544943704305
# Ratio of document which is equal or less than length 114 in entire document : 96.44068146334418
# Ratio of document which is equal or less than length 115 in entire document : 96.54797686271004
# Ratio of document which is equal or less than length 116 in entire document : 96.68553506702523
# Ratio of document which is equal or less than length 117 in entire document : 96.79970837660686
# Ratio of document which is equal or less than length 118 in entire document : 96.9186962233395
# Ratio of document which is equal or less than length 119 in entire document : 97.02461604066221
# Ratio of document which is equal or less than length 120 in entire document : 97.15116958863219
# Ratio of document which is equal or less than length 121 in entire document : 97.29766907622788
# Ratio of document which is equal or less than length 122 in entire document : 97.42009587806841
# Ratio of document which is equal or less than length 123 in entire document : 97.58447793222508
# Ratio of document which is equal or less than length 124 in entire document : 97.74198207616598
# Ratio of document which is equal or less than length 125 in entire document : 97.91668099564629
# Ratio of document which is equal or less than length 126 in entire document : 98.08725316899714
# Ratio of document which is equal or less than length 127 in entire document : 98.26814220767162
# Ratio of document which is equal or less than length 128 in entire document : 98.4662260218855
# Ratio of document which is equal or less than length 129 in entire document : 98.64092494136581
# Ratio of document which is equal or less than length 130 in entire document : 98.81493606982454
# Ratio of document which is equal or less than length 131 in entire document : 99.01233209301685
# Ratio of document which is equal or less than length 132 in entire document : 99.21247928029547
# Ratio of document which is equal or less than length 133 in entire document : 99.3864904087542
# Ratio of document which is equal or less than length 134 in entire document : 99.570130611515
# Ratio of document which is equal or less than length 135 in entire document : 99.7104399799165
# Ratio of document which is equal or less than length 136 in entire document : 99.81567200621762
# Ratio of document which is equal or less than length 137 in entire document : 99.90027030187147
# Ratio of document which is equal or less than length 138 in entire document : 99.95598137461914
# Ratio of document which is equal or less than length 139 in entire document : 99.98211743343902
# Ratio of document which is equal or less than length 140 in entire document : 100.0
# mean : 77.08363342310643, std : 28.064169304173113, var : 787.5975987332923
#
# By results of function choose optimal length roughly,
# 90% : length 70 (89.87502837137964%)
# 95% : length 100 (94.86426444189198)
# 99% : length 130 (98.81493606982454)

# %% [markdown]
# # 3-1. Tokenization
#
# ## Use Pretrained model : skt\kobert-base-v1  from Huggingface
# (https://github.com/SKTBrain/KoBERT)

# %%
# !pip install 'git+https://github.com/SKTBrain/KoBERT.git#egg=kobert_tokenizer&subdirectory=kobert_hf'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kobert_tokenizer
#   Cloning https://github.com/SKTBrain/KoBERT.git to /tmp/pip-install-haefs54i/kobert-tokenizer_9e2a76c799e841d39a41661e04e628d4
#   Running command git clone --filter=blob:none --quiet https://github.com/SKTBrain/KoBERT.git /tmp/pip-install-haefs54i/kobert-tokenizer_9e2a76c799e841d39a41661e04e628d4
#   Resolved https://github.com/SKTBrain/KoBERT.git to commit 47a69af87928fc24e20f571fe10c3cc9dd9af9a3
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: kobert_tokenizer
#   Building wheel for kobert_tokenizer (setup.py) ... done
#   Created wheel for kobert_tokenizer: filename=kobert_tokenizer-0.1-py3-none-any.whl size=4648 sha256=9cbe32fc49f059155b466423ca8f22d11e9276ce3fbe27763c424ebfcb0bed23
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e2utouet/wheels/f7/cb/29/1a737fe71e5108dc30b04ea4a990f78ed271fa537aaf3fce7c
# Successfully built kobert_tokenizer
# Installing collected packages: kobert_tokenizer
# Successfully installed kobert_tokenizer-0.1

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.4.0)

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 79.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.0 tokenizers-0.13.2 transformers-4.26.0

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.0 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
import torch
from transformers import BertForSequenceClassification
from kobert_tokenizer import KoBERTTokenizer

# Load pretrained kobert model
model = BertForSequenceClassification.from_pretrained('skt/kobert-base-v1')
# Load
tokenizer = KoBERTTokenizer.from_pretrained('skt/kobert-base-v1')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/535 [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/369M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at skt/kobert-base-v1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/371k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/244 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.

# %%
import torch
from transformers import BertConfig, BertModel, BertForPreTraining, BertTokenizer, BertForSequenceClassification
from unicodedata import normalize

tokenizer_krbert = BertTokenizer.from_pretrained('snunlp/KR-BERT-char16424', do_lower_case=False)
kr_bert_model = BertForSequenceClassification.from_pretrained('snunlp/KR-BERT-char16424')

# convert a string into sub-char
def to_subchar(string):
    return normalize('NFKD', string)

sentence = '토크나이저 예시입니다.'
print(tokenizer_krbert.tokenize(to_subchar(sentence)))
# Out:
# Some weights of the model checkpoint at snunlp/KR-BERT-char16424 were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at snunlp/KR-BERT-char16424 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ['ᄐ', '##ᅩ', '##ᄏ', '##ᅳ', '##ᄂ', '##ᅡ', '##ᄋ', '##ᅵ', '##ᄌ', '##ᅥ', 'ᄋ', '##ᅨ', '##ᄉ', '##ᅵ', '##ᄋ', '##ᅵ', '##ᆸ', '##ᄂ', '##ᅵ', '##ᄃ', '##ᅡ', '.']

# %%
text = X_train[1]

tokenized_text = tokenizer_krbert.tokenize(text)
print(tokenized_text)

input_ids = tokenizer_krbert.encode(text)
print(input_ids)

decoded_ids = tokenizer_krbert.decode(input_ids)
print(decoded_ids)
# Out:
# ['흠', '##포스', '##터', '##보고', '초', '##딩', '##영화', '##줄', '##오', '##버', '##연', '##기', '##조차', '가', '##볍', '##지', '않', '##구나']
# [2, 14091, 7518, 347, 2170, 361, 1973, 3429, 1889, 188, 556, 189, 41, 4589, 72, 9907, 32, 808, 5794, 3]
# [CLS] 흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나 [SEP]

# %%
text = X_train[1]

tokenized_text = tokenizer.tokenize(text)
print(tokenized_text)

input_ids = tokenizer.encode(text)
print(input_ids)

decoded_ids = tokenizer.decode(input_ids)
print(decoded_ids)
# Out:
# ['▁', '흠', '포', '스터', '보고', '▁초', '딩', '영화', '줄', '오', '버', '연', '기', '조차', '▁', '가', '볍', '지', '▁않', '구나']
# [2, 517, 7989, 7728, 6686, 6366, 4501, 5957, 6954, 7292, 6964, 6323, 6928, 5561, 7261, 517, 5330, 6359, 7318, 3146, 5496, 3]
# [CLS] 흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나[SEP]

# %%
inputs = tokenizer.batch_encode_plus([text], return_tensors='pt')

out = model(**inputs)

print(out.loss)
print(out.logits)
# Out:
# None
# tensor([[ 0.2134, -0.0648]], grad_fn=<AddmmBackward0>)

# %%
# kr_bert_model
inputs = tokenizer_krbert.batch_encode_plus([text], return_tensors='pt')

out = kr_bert_model(**inputs)

print(out.loss)
print(out.logits)
# Out:
# None
# tensor([[-0.1766,  0.0032]], grad_fn=<AddmmBackward0>)

# %%
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
import torch.nn.functional as F
import torch
from tqdm import tqdm

# %%
#  Returns a bool indicating if CUDA is currently available.
print(f"cuda avaliable : {torch.cuda.is_available()}")
 
#  Returns the index of a currently selected device.
print(f"cuda device num : {torch.cuda.current_device()}")
 
#  Returns the number of GPUs available.
print(f"entire cuda nums : {torch.cuda.device_count()}")
 
#  Gets the name of a device.
print(f"device name : {torch.cuda.get_device_name(0)}")
 
#  Context-manager that changes the selected device.
#  device (torch.device or int) – device index to select. 
print(torch.cuda.device(0))
# Out:
# cuda avaliable : False
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-3b0f70398b3c> in <module>
#       3
#       4 #  Returns the index of a currently selected device.
# ----> 5 print(f"cuda device num : {torch.cuda.current_device()}")
#       6
#       7 #  Returns the number of GPUs available.
#
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py in current_device()
#     550 def current_device() -> int:
#     551     r"""Returns the index of a currently selected device."""
# --> 552     _lazy_init()
#     553     return torch._C._cuda_getDevice()
#     554
#
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     227         if 'CUDA_MODULE_LOADING' not in os.environ:
#     228             os.environ['CUDA_MODULE_LOADING'] = 'LAZY'
# --> 229         torch._C._cuda_init()
#     230         # Some of the queued calls may reentrantly call _lazy_init();
#     231         # we need to just return without initializing in that case.
#
# RuntimeError: No CUDA GPUs are available

# %%
class NsmcDataset(Dataset):
    ''' Naver Sentiment Movie Corpus Dataset '''
    def __init__(self, df):
        self.df = df

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        text = self.df.iloc[idx, 1]
        label = torch.tensor(self.df.iloc[idx, 2])
        return text, label

# %%
# cuda empty cache
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
def train(model, max_len, learning_rate):
  batch = 32
  epochs = 5

  train_loss = 0
  train_len = 0
  train_correct = 0

  test_loss = 0
  test_len = 0
  test_correct = 0

  # train, test dataloader
  train_dataset = NsmcDataset(train_data)
  train_loader = DataLoader(train_dataset, batch_size=batch, shuffle=True, num_workers=2)

  test_dataset = NsmcDataset(test_data)
  test_loader = DataLoader(test_dataset, batch_size=batch, shuffle=False, num_workers=2)

  # set optimizer
  optimizer = AdamW(model.parameters(),
                  lr=learning_rate,
                  eps=1e-8
                  )

  # total train steps
  total_steps = len(train_loader) * epochs
  # learning rate schedular
  scheduler = get_linear_schedule_with_warmup(optimizer, 
                                              num_warmup_steps = 0,
                                              num_training_steps = total_steps)

  # CUDA device
  cuda = torch.device('cuda')
  model = model.cuda()

  for epoch in range(epochs):
    
    model.train()

    print('======== Epoch {:} / {:} ========'.format(epoch + 1, epochs))
    # initalize train loss

    train_loss = 0
    train_len = 0
    train_correct = 0

    
    for text, label in tqdm(train_loader,desc="train"):
      optimizer.zero_grad()
      
      # encoding and zero padding
      sample = tokenizer.batch_encode_plus(text, padding=True, truncation=True, max_length=max_len, return_tensors='pt')
      
      sample, label = sample.to(device=cuda), label.to(device=cuda)

      # forward
      outputs = model(**sample, labels=label)

      logits = outputs['logits']
      loss = outputs['loss']

      # get loss
      pred = torch.argmax(F.softmax(logits, dim=1), dim=1)
      correct = pred.eq(label)

      train_correct += correct.sum().item()
      train_len += len(label)
      train_loss += loss.item()

      # update gradient
      loss.backward()

      optimizer.step()
      scheduler.step()
      

    # test

    test_loss = 0
    test_len = 0
    test_correct = 0

    model.eval()

    for text, label in tqdm(test_loader,desc="test"):
      # encoding and zero padding
      sample = tokenizer.batch_encode_plus(text, padding=True, truncation=True, max_length=max_len, return_tensors='pt')
      
      sample, label = sample.to(device=cuda), label.to(device=cuda)
      
      # forward
      outputs = model(**sample, labels=label)

      logits = outputs['logits']
      loss = outputs['loss']
      
      #get accuracy
      pred = torch.argmax(F.softmax(logits, dim=1), dim=1)
      correct = pred.eq(label)

      test_correct += correct.sum().item()
      test_len += len(label)
      test_loss += loss.item()
    
    print('Test accuracy: ', test_correct / test_len)


    # Save model    
    model_name = "model"+ "_" + str(max_len) + "_" +str(epoch) + ".pt"
    PATH='/content/drive/My Drive/nsmc/'
    torch.save(model.state_dict(), PATH + model_name)

    # Save log
    log_file_curve = open(os.path.join(PATH, 'log_curve.txt'), 'a+')
    log_file_curve.write(str(epoch) + ',' + str(train_loss/train_len) + ',' + str(test_loss/test_len) + ',' + str(max_len) +',' + str(learning_rate) + '\n')
    log_file_curve.close()

# %% [markdown]
# ## Hyperparameter selection criteria
#
# KR-BERT is another korean language based on BERT.
# They experiments sentiment classification for downstream task with NSMC dataset.
#
# I used same fine-tuning hyperparameter in KR-BERT for KoBERT.
#
# Batch size : 32, 64
# Epochs : 5
# Learning rate : 1e-3, 2e-5, 5e-5
#
#
#
# [KR-BERT paper](https://arxiv.org/abs/2008.03979)

# %%
from transformers import AdamW
from transformers import get_linear_schedule_with_warmup
from itertools import product

import time

# hyperparameter
max_len = [70, 100, 130, 140]
learning_rate = [1e-3, 2e-5, 5e-5]

hyperparameter = product(max_len, learning_rate)

for x, y in hyperparameter:
  train(model, x, y)
print("Train finished ! ")

# %%
# 모델 불러오기
PATH='/content/drive/MyDrive/nsmc/model_70_3.pt'
model = BertForSequenceClassification.from_pretrained('skt/kobert-base-v1')
model.load_state_dict(torch.load(PATH))
model.eval()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at skt/kobert-base-v1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-f4e7412ee8c4> in <module>
#       2 PATH='/content/drive/MyDrive/nsmc/model_70_3.pt'
#       3 model = BertForSequenceClassification.from_pretrained('skt/kobert-base-v1')
# ----> 4 model.load_state_dict(torch.load(PATH))
#       5 model.eval()
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     787                     except RuntimeError as e:
#     788                         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 789                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     790         if weights_only:
#     791             try:
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1129     unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1130     unpickler.persistent_load = persistent_load
# -> 1131     result = unpickler.load()
#    1132
#    1133     torch._utils._validate_loaded_sparse_tensors()
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in persistent_load(saved_id)
#    1099         if key not in loaded_storages:
#    1100             nbytes = numel * torch._utils._element_size(dtype)
# -> 1101             load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1102
#    1103         return loaded_storages[key]
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in load_tensor(dtype, numel, key, location)
#    1081         # stop wrapping with TypedStorage
#    1082         loaded_storages[key] = torch.storage.TypedStorage(
# -> 1083             wrap_storage=restore_location(storage, location),
#    1084             dtype=dtype)
#    1085
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in default_restore_location(storage, location)
#     213 def default_restore_location(storage, location):
#     214     for _, _, fn in _package_registry:
# --> 215         result = fn(storage, location)
#     216         if result is not None:
#     217             return result
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in _cuda_deserialize(obj, location)
#     180 def _cuda_deserialize(obj, location):
#     181     if location.startswith('cuda'):
# --> 182         device = validate_cuda_device(location)
#     183         if getattr(obj, "_torch_load_uninitialized", False):
#     184             with torch.cuda.device(device):
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in validate_cuda_device(location)
#     164
#     165     if not torch.cuda.is_available():
# --> 166         raise RuntimeError('Attempting to deserialize object on a CUDA '
#     167                            'device but torch.cuda.is_available() is False. '
#     168                            'If you are running on a CPU-only machine, '
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
def test_sentences(new_sentence):
    new_sentence = new_sentence.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
    new_sentence = tokenizer.batch_encode_plus([new_sentence], return_tensors='pt')
    
    # 예측
    with torch.no_grad():
      outputs = model(**new_sentence)
    
    logits = outputs['logits']
    
    pred = torch.argmax(logits, dim=1)
    score = F.softmax(logits, dim=1)
    score = (score[0][pred]).item()

    # print result
    if(pred > 0.5):
      print("{:2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
    else:
      print("{:2f}% 확률로 부정 리뷰입니다.\n".format(score * 100))

# %%
test_sentences('이 영화 꿀잼 ㅋㅋㅋ')
test_sentences('이 영화 노잼 ㅋㅋㅋ')
test_sentences('내가 널 좋아할거 같냐?ㅋㅋㅋ')
